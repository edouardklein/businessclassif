# %%
import pickle
d = pickle.load(open('Exp6/cat2year_cik.pickle', 'rb'))
d
# Out:
# {100: [(1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
#   (1998, 783324),
# ...
